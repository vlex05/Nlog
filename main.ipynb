# %%
from src import config
from src.data_frame import DataFrame
from src.checking_trades import CheckingTrades
from src.google_sheet import GoogleSheet
import warnings
import time
warnings.filterwarnings("ignore")

# %%
scrap = DataFrame()

# %%
trade_action = CheckingTrades()

# %%
while True:
    df = scrap.update_dataframe()
    trade_action.check_if_same()
    time.sleep(10)
# Out:
# Il n'y a qu'une seule ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Il n'y a qu'une seule ligne pour le trader Ketepeng.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-dbd8a4.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-e8c695.
#
# Il n'y a qu'une seule ligne pour le trader xotxot.
#
# Il n'y a qu'une seule ligne pour le trader A-Tuhi.
#
# Il n'y a qu'une seule ligne pour le trader TreeOfAlpha1.
#
# Il n'y a qu'une seule ligne pour le trader elonier.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-1a8e8.
#
# Il n'y a qu'une seule ligne pour le trader 0xKyd.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-016ab5.
#
# Il n'y a qu'une seule ligne pour le trader Side-sleep.
#
# Il n'y a qu'une seule ligne pour le trader Kimchimin.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-68d688.
#
# Il n'y a qu'une seule ligne pour le trader Anonymous User-81ba19.
#
# Il n'y a qu'une seule ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données ne sont pas les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Il n'y a aucune ouverture 🚨 ni fermeture 🔒 de trade, il y a donc un changement de volume 📊 dans une position pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# ...
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Cho***aro.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Ketepeng.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-dbd8a4.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-e8c695.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader xotxot.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader A-Tuhi.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader TreeOfAlpha1.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader elonier.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-1a8e8.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader 0xKyd.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-016ab5.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Side-sleep.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Kimchimin.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-68d688.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader Anonymous User-81ba19.
#
# Les données sont les mêmes entre la dernière ligne et l'avant-dernière ligne pour le trader CnTraderT.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 while True:
# ----> 2     df = scrap.update_dataframe()
#       3     trade_action.check_if_same()
#       4     time.sleep(10)
#
# File ~\N-log\src\data_frame.py:56, in DataFrame.update_dataframe(self)
#      53 except:
#      54     #print("la page met du temps a chargé, verifiez la conexion internet.")
#      55     pass
# ---> 56 time.sleep(3)
#      57 trader_scraper = TraderScraper(self.driver, self.XPATH_TRADER_NAME, self.XPATH_ROI_PNL, self.XPATH_TRADES_TABLE, self.XPATH_NO_POSITIONS_MESSAGE)
#      58 trader_name = trader_scraper.get_trader_name()
#
# KeyboardInterrupt:

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
